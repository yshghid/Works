# %%
import psycopg2
import pandas as pd
import os
from dotenv import load_dotenv
from openai import OpenAI

os.chdir("/Users/yshmbid/Documents/home/github/SQL")

# 1. .env 파일 로드
load_dotenv()

# 2. OpenAI Client 생성
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# 3. DB 연결
conn = psycopg2.connect(
    host="localhost",
    port=5432,
    database="postgres",
    user="postgres",
    password=os.getenv("PG_PASSWORD"),
)
cursor = conn.cursor()

# 4. 임베딩 함수
def get_embedding(text: str):
    response = client.embeddings.create(
        input=text,
        model="text-embedding-3-small"  # 또는 "text-embedding-3-large"
    )
    return response.data[0].embedding

# 5. DB 삽입 함수 (트랜잭션 포함)
def insert_design(description: str):
    try:
        cursor.execute("BEGIN;")  # 트랜잭션 시작

        # 임베딩 생성
        embedding = get_embedding(description)

        # design 테이블에 삽입
        cursor.execute(
            "INSERT INTO design (description, embedding) VALUES (%s, %s)",
            (description, embedding)
        )

        conn.commit()
        print(f"[COMMIT] 등록 성공 → {description[:40]}...")

    except Exception as e:
        conn.rollback()
        print(f"[ROLLBACK] 실패 → {description[:40]}... 에러: {e}")

# 6. CSV 파일 로드 & 처리
df = pd.read_csv("sample_designs_500.csv")

for idx, row in df.iterrows():
    desc = row.get("description")
    if pd.notna(desc):  # description이 비어있지 않을 때만 실행
        insert_design(desc)

# 7. 연결 종료
cursor.close()
conn.close()
# Out:
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Maybe...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. M...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Simpl...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. M...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Up en...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. S...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Their...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Ev...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. For s...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. An...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. A...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. T...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Ident...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Wh...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Ha...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. T...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. A...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Heavy...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Stop ...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Fe...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. A...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Perha...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. B...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Di...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Me tr...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. A...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. B...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. D...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Peopl...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. T...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. M...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Membe...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Never...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Minut...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. L...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Recen...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Campa...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. A...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. La...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. B...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. F...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. E...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Nearl...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. P...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. S...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. S...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. C...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Or...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. R...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. L...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. M...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. N...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Sm...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Af...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Impor...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Anoth...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. P...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Respo...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Ye...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Troub...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Po...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. E...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. P...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. I...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. A...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Towar...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Ty...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Relig...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. A...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Pa...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. P...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Co...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. E...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Image...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. C...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. S...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Ar...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. S...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. To no...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Da...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. T...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Ma...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. H...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Rule ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. On...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. H...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. R...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. A...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. J...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. S...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. L...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. A...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. N...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. B...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. C...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. I...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. R...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. O...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. E...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. K...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. I...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. D...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. A...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Re...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. R...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. L...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. I...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Phone...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. A...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. E...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Ev...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Arriv...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Wh...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. B...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Back ...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Natio...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. E...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Re...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Use b...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. O...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Ki...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Recen...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. S...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. G...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Co...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. T...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Wh...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Infor...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Nu...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Me...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. F...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. S...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Pm...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. B...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Whole...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. E...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. H...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. B...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. B...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. H...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. S...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. I ...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Inter...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Find ...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Accor...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Wi...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Mu...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. E...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Simpl...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. E...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. In...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Enoug...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Rate ...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Ma...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Go...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Fa...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Ce...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. M...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. E...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Te...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Parti...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. N...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Of...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Loss ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. P...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Infor...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Br...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. S...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. A...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. N...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. I...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. H...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. E...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. D...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Bo...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. C...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. D...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. St...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Less ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. R...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. T...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. N...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. S...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Watch...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Ci...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Think...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Up it...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. T...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. It...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. T...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. Y...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. His d...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Simil...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Fr...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. T...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. D...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Suppo...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. F...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. S...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. W...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. W...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. E...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. F...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Li...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Fo...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. T...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Offic...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Vo...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. G...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. D...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. S...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. P...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Pr...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. True ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. S...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. A...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Baby ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Th...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Co...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. C...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Newsp...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. D...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. M...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. La...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. O...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. P...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Perfo...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Le...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. S...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Po...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Imagi...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Citiz...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. W...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. N...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. I...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. H...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. R...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. B...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Se...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Head ...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. B...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. St...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. Y...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Up co...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. L...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. No...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. L...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Share...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. A...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Type ...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Fast ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. R...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. P...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. R...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. G...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Nu...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Out l...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Piece...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. W...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. S...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. K...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. I...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. I...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. In...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. D...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. R...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. His a...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Vo...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. I...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. South...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Re...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. P...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Book ...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Bo...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. S...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Ef...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Syste...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Momen...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. S...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. U...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Tr...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. In...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Th...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. I...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Third...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. W...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. W...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. K...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. C...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. M...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. D...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. B...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Progr...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Work ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Weigh...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Drop ...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. T...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Im...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. A...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. S...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Me...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Fo...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. N...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Fi...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Ki...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Camer...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Usual...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Measu...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. B...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. F...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Try s...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Cold ...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Co...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. In...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Da...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. D...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Artic...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. To...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. R...
# [COMMIT] 등록 성공 → 태양광 패널과 지열 에너지를 활용하여 에너지 자립을 목표로 합니다. Ra...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. S...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. I...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. S...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. I...
# [COMMIT] 등록 성공 → 이 설계안은 자연 채광과 환기를 최대화하기 위한 구조로 설계되었습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. E...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. P...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. R...
# [COMMIT] 등록 성공 → AI 시스템을 활용하여 실시간 환경 제어가 가능하도록 구성되었습니다. S...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. A des...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Centu...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Analy...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. P...
# [COMMIT] 등록 성공 → 모듈러 구조를 활용하여 빠른 시공이 가능하도록 설계되었습니다. Gas o...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. I...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. L...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. A...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
# [COMMIT] 등록 성공 → 도심 속 자연을 구현하기 위한 녹지 공간을 적극적으로 배치하였습니다. S...
# [COMMIT] 등록 성공 → 사용자 동선을 고려하여 공용 공간과 개인 공간을 명확히 구분하였습니다. ...
